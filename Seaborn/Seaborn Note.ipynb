# %% [markdown]
# # Welcome to SEABORN

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Countplot

# %%
mart=pd.read_excel("supermarket_sales.xlsx")
mart
# Out:
#       Invoice ID Branch      City Customer type  Gender  \
# 0    692-92-5582      B  Mandalay        Member  Female
# 1    351-62-0822      B  Mandalay        Member  Female
# 2    529-56-3974      B  Mandalay        Member    Male
# 3    299-46-1805      B  Mandalay        Member  Female
# 4    319-50-3348      B  Mandalay        Normal  Female
# ..           ...    ...       ...           ...     ...
# 995  886-18-2897      A    Yangon        Normal  Female
# 996  745-74-0715      A    Yangon        Normal    Male
# 997  727-02-1313      A    Yangon        Member    Male
# 998  347-56-2442      A    Yangon        Normal    Male
# 999  849-09-3807      A    Yangon        Member  Female
#
#                Product line  Unit price  Quantity  Tax 5%    Total  \
# 0        Food_and_beverages       54.84         3   8.226  172.746
# 1       Fashion_accessories       14.48         4   2.896   60.816
# 2    Electronic_accessories       25.51         4   5.102  107.142
# ...

# %%
mart.shape
# Out:
# (1000, 17)

# %%
mart.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
mart.head()
# Out:
#     Invoice ID Branch      City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Mandalay        Member  Female      Food_and_beverages
# 1  351-62-0822      B  Mandalay        Member  Female     Fashion_accessories
# 2  529-56-3974      B  Mandalay        Member    Male  Electronic_accessories
# 3  299-46-1805      B  Mandalay        Member  Female       Sports_and_travel
# 4  319-50-3348      B  Mandalay        Normal  Female      Home_and_lifestyle
#
#    Unit price  Quantity  Tax 5%    Total                 Date      Time  \
# 0       54.84         3   8.226  172.746            2/20/2019  13:27:00
# 1       14.48         4   2.896   60.816  2019-06-02 00:00:00  18:07:00
# 2       25.51         4   5.102  107.142  2019-09-03 00:00:00  17:03:00
# 3       93.72         6  28.116  590.436            1/15/2019  16:19:00
# 4       40.30         2   4.030   84.630  2019-11-03 00:00:00  15:30:00
#
# ...

# %% [markdown]
# ***Simple countplot***

# %%
sns.countplot(x="Gender",data=mart)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x="Payment",data=mart)
# Out:
# <Axes: xlabel='Payment', ylabel='count'>

# %%
sns.countplot(x="Rating",data=mart)
# Out:
# <Axes: xlabel='Rating', ylabel='count'>

# %%
sns.countplot(x="Quantity",data=mart)
# Out:
# <Axes: xlabel='Quantity', ylabel='count'>

# %%
sns.countplot(x="Product line",data=mart)
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %% [markdown]
# ***Using figsize***

# %%
plt.figure(figsize=(15,5))
sns.countplot(x="Product line",data=mart)
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %% [markdown]
# ***Horizontal Bar***

# %%
sns.countplot(y="Product line",data=mart)
# Out:
# <Axes: xlabel='count', ylabel='Product line'>

# %% [markdown]
# ***Add hue to get the count on two categories i.e. Product line and Gender***

# %%
plt.figure(figsize=(15,5))
sns.countplot(x="Product line",hue="Gender",data=mart)
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %% [markdown]
# ***Using different color palette***

# %%
plt.figure(figsize=(15,5))
sns.countplot(x="Product line",hue="Gender",data=mart,palette='hls')
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %% [markdown]
# ***Change Style using facecolor, linewidth and edge color***

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='Product line',data=mart
             ,facecolor = (0,1,1,0)
             ,linewidth=5
             ,edgecolor=sns.color_palette('dark',3))
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %% [markdown]
# # Bar plot

# %% [markdown]
# ***Display the SEBORN dataset names and load one of them***

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('titanic')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ***Create a basic Bar plot***

# %%
mart.head()
# Out:
#     Invoice ID Branch      City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Mandalay        Member  Female      Food_and_beverages
# 1  351-62-0822      B  Mandalay        Member  Female     Fashion_accessories
# 2  529-56-3974      B  Mandalay        Member    Male  Electronic_accessories
# 3  299-46-1805      B  Mandalay        Member  Female       Sports_and_travel
# 4  319-50-3348      B  Mandalay        Normal  Female      Home_and_lifestyle
#
#    Unit price  Quantity  Tax 5%    Total                 Date      Time  \
# 0       54.84         3   8.226  172.746            2/20/2019  13:27:00
# 1       14.48         4   2.896   60.816  2019-06-02 00:00:00  18:07:00
# 2       25.51         4   5.102  107.142  2019-09-03 00:00:00  17:03:00
# 3       93.72         6  28.116  590.436            1/15/2019  16:19:00
# 4       40.30         2   4.030   84.630  2019-11-03 00:00:00  15:30:00
#
# ...

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='Product line',y='Total',data=mart)
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %% [markdown]
# ***Add HUE to the barplot***

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='Product line',y='Total',hue='Gender',data=mart)
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %% [markdown]
# ***Make the barplot HORIZONTAL***

# %%
#plt.figure(figsize=(15,5))
sns.barplot(y='Product line',x='Total',hue='Gender',data=mart)
# Out:
# <Axes: xlabel='Total', ylabel='Product line'>

# %% [markdown]
# ***Plot the bars in a given ORDER***

# %% [markdown]
# ***Alphabetical ordered***

# %%
x=mart['Product line'].sort_values()
x.unique()
# Out:
# array(['Electronic_accessories', 'Fashion_accessories',
#        'Food_and_beverages', 'Health_and_beauty', 'Home_and_lifestyle',
#        'Sports_and_travel'], dtype=object)

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='Product line',y='Total',hue='Gender',data=mart,order=['Electronic_accessories', 'Fashion_accessories',
       'Food_and_beverages', 'Health_and_beauty', 'Home_and_lifestyle',
       'Sports_and_travel'])
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,5))
ordered_columns=mart['Product line'].sort_values().unique()
sns.barplot(x='Product line',y='Total',hue='Gender',data=mart,order=ordered_columns)
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,5))
ordered_columns=mart['Product line'].sort_values().unique()
sns.barplot(x='Product line',y='Total',hue='Gender',data=mart,order=ordered_columns,hue_order=['Male','Female'])
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %% [markdown]
# ***Add CAP on the ERROR BAR***

# %%
plt.figure(figsize=(15,5))
ordered_columns=mart['Product line'].sort_values().unique()
sns.barplot(x='Product line',y='Total',hue='Gender',data=mart,order=ordered_columns,capsize=0.2)
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %% [markdown]
# ***REMOVE the error bar using ci***

# %%
plt.figure(figsize=(15,5))
ordered_columns=mart['Product line'].sort_values().unique()
sns.barplot(x='Product line',y='Total',hue='Gender',data=mart,order=ordered_columns,ci=None)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_2184\1711878095.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Product line',y='Total',hue='Gender',data=mart,order=ordered_columns,ci=None)
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,5))
ordered_columns=mart['Product line'].sort_values().unique()
sns.barplot(x='Product line',y='Total',hue='Gender',data=mart,order=ordered_columns,errorbar=None)
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %% [markdown]
# ***Change bar colors using COLOR attribute***

# %%
plt.figure(figsize=(15,5))
ordered_columns=mart['Product line'].sort_values().unique()
sns.barplot(x='Product line',y='Total',hue='Gender',data=mart,order=ordered_columns,errorbar=None,color='red')
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_2184\456718235.py:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:red'` for the same effect.
#
#   sns.barplot(x='Product line',y='Total',hue='Gender',data=mart,order=ordered_columns,errorbar=None,color='red')
# <Axes: xlabel='Product line', ylabel='Total'>

# %% [markdown]
# ***Change color using PALLETE attribute***

# %%
plt.figure(figsize=(15,5))
ordered_columns=mart['Product line'].sort_values().unique()
sns.barplot(x='Product line',y='Total',hue='Gender',data=mart,order=ordered_columns,errorbar=None,palette='dark:red')
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %% [markdown]
# ***Using SATURATION parameter***

# %%
plt.figure(figsize=(15,5))
ordered_columns=mart['Product line'].sort_values().unique()
sns.barplot(x='Product line',y='Total',hue='Gender',data=mart,order=ordered_columns,errorbar=None,palette='dark:red',saturation=0.5)
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %% [markdown]
# ***Change default aggregation method using ESTIMATOR parameter***

# %%
plt.figure(figsize=(15,5))
ordered_columns=mart['Product line'].sort_values().unique()
sns.barplot(x='Product line',y='Total',hue='Gender',data=mart,order=ordered_columns,errorbar=None,palette='dark:red',estimator=np.median)
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,5))
ordered_columns=mart['Product line'].sort_values().unique()
sns.barplot(x='Product line',y='Total',hue='Gender',data=mart,order=ordered_columns,errorbar=None,palette='dark:red',estimator=sum)
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %% [markdown]
# # Box plot

# %% [markdown]
# ***Create a basic BOX plot on one NUMERIC variable***

# %%
sns.boxplot(x='Total',data=mart,width=0.5)
# Out:
# <Axes: xlabel='Total'>

# %%
sns.boxplot(y='Total',data=mart,width=0.2)
# Out:
# <Axes: ylabel='Total'>

# %% [markdown]
# ***Create a basic BOX plot on one numeric variable by a CATEGORICAL variable***

# %%
sns.boxplot(y='Total',x='Payment',data=mart)
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %% [markdown]
# ***Create a basic BOX plot on one numeric variable by TWO CATEGORICAL variable using HUE attribute***

# %%
sns.boxplot(y='Total',x='Payment',hue='Gender',data=mart)
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %% [markdown]
# ***Add MEAN marker in the box plot using Showmeans attribute and change its style using meanprops***

# %%
sns.boxplot(y='Total',x='Payment',hue='Gender',data=mart,showmeans=True)
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %%
sns.boxplot(y='Total',x='Payment',hue='Gender',data=mart,showmeans=True,meanprops={"marker": "o",
                                                                                  "markerfacecolor":"white"
                                                                                  ,"markersize":"5"
                                                                                  ,"markeredgecolor":"black"})
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %% [markdown]
# ***Make HORIZONTAL box plot***

# %%
sns.boxplot(x='Total',y='Payment',hue='Gender',data=mart,showmeans=True,meanprops={"marker": "o",
                                                                                  "markerfacecolor":"white"
                                                                                  ,"markersize":"5"
                                                                                  ,"markeredgecolor":"black"})
# Out:
# <Axes: xlabel='Total', ylabel='Payment'>

# %% [markdown]
# ***Change PALETTE, LINE WIDTH etc..***

# %%
sns.boxplot(y='Total',x='Payment',hue='Gender',data=mart,showmeans=True,meanprops={"marker":"o"
                                                                                  ,"markerfacecolor":"white"
                                                                                  ,"markersize":"5"
                                                                                  ,"markeredgecolor":"black"},palette='CMRmap',linewidth=5)
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %% [markdown]
# ***Create box plot for EACH OF THE NUMERIC VARIABLE in the dataframe***

# %%
plt.figure(figsize=(15,5))
sns.boxplot(data=mart)
# Out:
# <Axes: >

# %% [markdown]
# # Violin Plot

# %% [markdown]
# ***Create a basic Violin Plot***

# %%
sns.violinplot(y='Total',data=mart)
# Out:
# <Axes: ylabel='Total'>

# %% [markdown]
# ***Create a VIOLINPLOT on two categorical and one numeric variable and use split***

# %%
sns.violinplot(y='Total',x='Payment',data=mart)
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %%
sns.violinplot(y='Total',x='Payment',hue='Gender',data=mart)
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %%
sns.violinplot(y='Total',x='Payment',hue='Gender',data=mart,split=True)
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %% [markdown]
# ***Change the box in the Violin Plot to horzontal lines***

# %%
sns.violinplot(x='Payment',y='Total',hue='Gender',data=mart,split=True,inner='quartile')
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %% [markdown]
# ***Draw line for each observations in a Violin Plot***

# %%
sns.violinplot(x='Payment',y='Total',hue='Gender',data=mart,split=True,inner='stick')
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %% [markdown]
# ***Change the amount of smoothing using bw attribute***

# %%
sns.violinplot(x='Payment',y='Total',hue='Gender',data=mart,split=True,inner='quartile',bw_method=.2)
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %% [markdown]
# ***Cut out the extreme values***

# %%
sns.violinplot(x='Payment',y='Total',hue='Gender',data=mart,split=True,inner='quartile',bw_method=.2,cut=0)
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %% [markdown]
# # Strip Plot

# %% [markdown]
# ***Create a basic Strip Plot***

# %%
sns.stripplot(data=mart, y='Total')
# Out:
# <Axes: ylabel='Total'>

# %%
sns.stripplot(data=mart, x='Total')
# Out:
# <Axes: xlabel='Total'>

# %% [markdown]
# ***Expand markers in Strip plot using jitter***

# %%
sns.stripplot(data=mart,y='Total',jitter=1)
# Out:
# <Axes: ylabel='Total'>

# %% [markdown]
# ***Draw line around the points using Linewidth***

# %%
sns.stripplot(data=mart,y='Total',linewidth=0.2)
# Out:
# <Axes: ylabel='Total'>

# %% [markdown]
# ***Include third categorical variable with hue***

# %%
sns.stripplot(data=mart,y='Total',x='Payment')
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %%
sns.stripplot(data=mart,y='Total',x='Payment',hue='Gender')
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %% [markdown]
# ***Separate each level of hue using DODGE***

# %%
sns.stripplot(data=mart, y='Total',x='Payment',hue='Gender',jitter=0.2,linewidth=0.5,dodge=True)
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %% [markdown]
# ***Draw the strips on top of Violin Plot***

# %%
sns.stripplot(data=mart, y='Total',x='Payment',jitter=0.1)
sns.violinplot(data=mart, y='Total',x='Payment',color='gray')
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %% [markdown]
# ***Draw the strips on top of Box Plot***

# %%
sns.stripplot(data=mart, y='Total',x='Payment',color="blue")
sns.boxplot(data=mart, y='Total',x='Payment',color='gray')
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %% [markdown]
# # Swarm Plot

# %% [markdown]
# ***Create a basic Swarm Plot***

# %%
sns.swarmplot(y='Total',data=mart)
# Out:
# <Axes: ylabel='Total'>

# %%
sns.swarmplot(x='Total',data=mart)
# Out:
# <Axes: xlabel='Total'>

# %% [markdown]
# ***Create Swarm Plot group by categories****

# %%
sns.swarmplot(y='Total',x='Payment',data=mart)
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %%
sns.swarmplot(y='Total',x='Payment',hue='Gender',data=mart)
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %% [markdown]
# ***Showing Hues Separatly on the categorical axis***

# %%
sns.swarmplot(y='Total',x='Payment',hue='Gender',data=mart,dodge=True)
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %% [markdown]
# ***Styling a SWARM - Change the marker, size, color, edge color***

# %%
sns.swarmplot(data=mart,y='Total',x='Payment',size=5)
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %%
sns.swarmplot(data=mart,y='Total',x='Payment',size=5,color='red')
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %%
sns.swarmplot(data=mart,y='Total',x='Payment',size=5,color='red',edgecolor='black')
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %%
sns.swarmplot(data=mart,y='Total',x='Payment',size=5,color='red',edgecolor='black',marker='*')
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %% [markdown]
# ***Overlay a SWARM PLOT on a BOX PLOT***

# %%
sns.boxplot(data=mart,y='Total',x='Payment')
sns.swarmplot(data=mart,y='Total',x='Payment',size=5,color='black')
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %% [markdown]
# ***Overlay a SWARM PLOT on a VIOLIN PLOT***

# %%
sns.violinplot(data=mart,y='Total',x='Payment',inner=None,width=1)
sns.swarmplot(data=mart,y='Total',x='Payment',size=4,color='white')
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %% [markdown]
# # Cat Plot

# %%
#By default it's a strip plot
sns.catplot(y='Total',x='Payment',data=mart)

# %%
sns.catplot(y='Total',x='Payment',data=mart,kind='bar')
#Options are 'strip', 'swarm', 'box', 'boxen', 'violin', 'bar', 'count', and 'point'.

# %%
sns.catplot(y='Total',x='Payment',data=mart,kind='box')

# %%
sns.catplot(y='Total',x='Payment',data=mart,kind='boxen')

# %%
sns.catplot(y='Total',x='Payment',data=mart,kind='violin')

# %%
sns.catplot(y='Payment',data=mart,kind='count')

# %%
sns.catplot(y='Total',x='Payment',data=mart,kind='point')

# %%
sns.catplot(y='Total',x='Payment',hue='Gender',data=mart,kind='violin')

# %%
sns.catplot(y='Total',x='Payment',col='Gender',data=mart,kind='violin')

# %%
sns.catplot(y='Total',x='Payment',col='Gender',row='Customer type',data=mart,kind='violin')
